# %% [markdown]
# 11/09/2024 - QUARTA-FEIRA

# %%
import pandas as pd

# %%
base = pd.read_csv('Banco de Dados Laboratorio.csv')

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   IDCOLABORADOR            1470 non-null   int64
#  1   IDADE                    1470 non-null   int64
#  2   INSATISTFEITO            1470 non-null   object
#  3   STATUSCIVIL              1470 non-null   object
#  4   GENERO                   1470 non-null   object
#  5   NOME                     1470 non-null   object
#  6   SETOR                    1470 non-null   object
#  7   CARGO                    1470 non-null   object
#  8   CEP                      1426 non-null   float64
#  9   NIVELEDUCACAO            1470 non-null   int64
#  10  FORMACAO                 1470 non-null   object
#  11  RENDAMENSAL              1470 non-null   int64
#  12  DESCONTOULTIMAFATURA     1470 non-null   object
#  13  ANONAEMPRESA             1470 non-null   int64
# ...

# %%
type(base)
# Out:
# pandas.core.frame.DataFrame

# %%
base
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 4                20     29           Nao  Divorciado   Feminino
# ...             ...    ...           ...         ...        ...
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1467           2064     27           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                 NOME      SETOR                   CARGO   CEP  NIVELEDUCACAO  \
# 0     Maria da Silva  Alimentos                 Auditor   1.0              2
# ...

# %%
base.head(2)
# Out:
#    IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL    GENERO            NOME  \
# 0              1     41           Sim    Solteiro  Feminino  Maria da Silva
# 1              5     33           Nao      Casado  Feminino    Ana Oliveira
#
#        SETOR        CARGO  CEP  NIVELEDUCACAO          FORMACAO  RENDAMENSAL  \
# 0  Alimentos      Auditor  1.0              2  Ciencias Sociais        19479
# 1      Saude  Pesquisador  3.0              4  Ciencias Sociais        23159
#
#   DESCONTOULTIMAFATURA  ANONAEMPRESA  ANOSMESMAPOSICAO  \
# 0                  Sim             6                 4
# 1                  Sim             8                 7
#
#    ANOSDESDEULTIMAPROMOCAO
# 0                        0
# 1                        3

# %%
type(base['CEP'])
# Out:
# pandas.core.series.Series

# %%
base.columns
# Out:
# Index(['IDCOLABORADOR', 'IDADE', 'INSATISTFEITO', 'STATUSCIVIL', 'GENERO',
#        'NOME', 'SETOR', 'CARGO', 'CEP', 'NIVELEDUCACAO', 'FORMACAO',
#        'RENDAMENSAL', 'DESCONTOULTIMAFATURA', 'ANONAEMPRESA',
#        'ANOSMESMAPOSICAO', 'ANOSDESDEULTIMAPROMOCAO'],
#       dtype='object')

# %%
base_genero = base['GENERO']

# %%
base[['GENERO']]
# Out:
#          GENERO
# 0      Feminino
# 1      Feminino
# 2      Feminino
# 3      Feminino
# 4      Feminino
# ...         ...
# 1465  Masculino
# 1466  Masculino
# 1467  Masculino
# 1468  Masculino
# 1469  Masculino
#
# [1470 rows x 1 columns]

# %%
base[['IDADE', 
      'INSATISTFEITO', 
      'STATUSCIVIL',
      'GENERO']]
# Out:
#       IDADE INSATISTFEITO STATUSCIVIL     GENERO
# 0        41           Sim    Solteiro   Feminino
# 1        33           Nao      Casado   Feminino
# 2        59           Nao      Casado   Feminino
# 3        29           Nao    Solteiro   Feminino
# 4        29           Nao  Divorciado   Feminino
# ...     ...           ...         ...        ...
# 1465     36           Nao      Casado  Masculino
# 1466     39           Nao      Casado  Masculino
# 1467     27           Nao      Casado  Masculino
# 1468     49           Nao      Casado  Masculino
# 1469     34           Nao      Casado  Masculino
#
# [1470 rows x 4 columns]

# %%
base['STATUSCIVIL'] == "Solteiro"
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: STATUSCIVIL, Length: 1470, dtype: bool

# %%
base[(base['STATUSCIVIL'] == "Solteiro")]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 7                28     34           Nao    Solteiro   Feminino
# 9                33     32           Sim    Solteiro   Feminino
# 11               38     46           Nao    Solteiro   Feminino
# ...             ...    ...           ...         ...        ...
# 1449           2021     21           Nao    Solteiro  Masculino
# 1450           2022     39           Nao    Solteiro  Masculino
# 1458           2038     32           Nao    Solteiro  Masculino
# 1460           2048     40           Nao    Solteiro  Masculino
# 1464           2057     31           Nao    Solteiro  Masculino
#
#                     NOME      SETOR                   CARGO   CEP  \
# 0         Maria da Silva  Alimentos                 Auditor   1.0
# ...

# %%
lista = ['Solteiro', 'Casado']
base[base['STATUSCIVIL'].isin(lista)]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 5                23     53           Nao      Casado   Feminino
# ...             ...    ...           ...         ...        ...
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1467           2064     27           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                  NOME      SETOR                   CARGO   CEP  NIVELEDUCACAO  \
# 0      Maria da Silva  Alimentos                 Auditor   1.0              2
# ...

# %%
base['STATUSCIVIL'].str.contains("Sol")
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: STATUSCIVIL, Length: 1470, dtype: bool

# %%
base[base['STATUSCIVIL'].str.contains("Sol")]
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 7                28     34           Nao    Solteiro   Feminino
# 9                33     32           Sim    Solteiro   Feminino
# 11               38     46           Nao    Solteiro   Feminino
# ...             ...    ...           ...         ...        ...
# 1449           2021     21           Nao    Solteiro  Masculino
# 1450           2022     39           Nao    Solteiro  Masculino
# 1458           2038     32           Nao    Solteiro  Masculino
# 1460           2048     40           Nao    Solteiro  Masculino
# 1464           2057     31           Nao    Solteiro  Masculino
#
#                     NOME      SETOR                   CARGO   CEP  \
# 0         Maria da Silva  Alimentos                 Auditor   1.0
# ...

# %%
base_sol = base[base['STATUSCIVIL'].str.contains("Sol")][['IDADE', 'INSATISTFEITO']]

# %%
base_sol
# Out:
#       IDADE INSATISTFEITO
# 0        41           Sim
# 3        29           Nao
# 7        34           Nao
# 9        32           Sim
# 11       46           Nao
# ...     ...           ...
# 1449     21           Nao
# 1450     39           Nao
# 1458     32           Nao
# 1460     40           Nao
# 1464     31           Nao
#
# [470 rows x 2 columns]

# %% [markdown]
# FUNÇÕES DE AGREGAÇÃO

# %%
base['RENDAMENSAL'].mean()
# Out:
# 14313.103401360544

# %%
base['CARGO'].value_counts()
# Out:
# CARGO
# Auditor                   326
# Pesquisador               292
# Tecnico de Laboratorio    259
# Diretor de Manufatura     145
# Representante da Saude    131
# Gestor                    102
# Representante de Setor     83
# Diretor de Pesquisa        80
# Tecnico de TI              52
# Name: count, dtype: int64

# %%
import pandas as pd

base.groupby(['CARGO'])['RENDAMENSAL'].mean()
# Out:
# CARGO
# Auditor                   14471.110429
# Diretor de Manufatura     14478.965517
# Diretor de Pesquisa       15080.550000
# Gestor                    15139.578431
# Pesquisador               13927.113014
# Representante da Saude    14400.198473
# Representante de Setor    14278.204819
# Tecnico de Laboratorio    14066.061776
# Tecnico de TI             13292.403846
# Name: RENDAMENSAL, dtype: float64

# %%
base.groupby(['CARGO'])['RENDAMENSAL']

# %%
base.groupby(['CARGO'])[['RENDAMENSAL', 'IDADE']].mean() # media das colunas renda e idade por cargo
# Out:
#                          RENDAMENSAL      IDADE
# CARGO
# Auditor                 14471.110429  36.889571
# Diretor de Manufatura   14478.965517  38.296552
# Diretor de Pesquisa     15080.550000  44.000000
# Gestor                  15139.578431  46.764706
# Pesquisador             13927.113014  34.236301
# Representante da Saude  14400.198473  39.809160
# Representante de Setor  14278.204819  30.361446
# Tecnico de Laboratorio  14066.061776  34.096525
# Tecnico de TI           13292.403846  35.500000

# %%
base.groupby(['CARGO']).agg({'RENDAMENSAL': ['sum', 'mean', 'count'] , 'IDADE': 'mean'})
# Out:
#                        RENDAMENSAL                          IDADE
#                                sum          mean count       mean
# CARGO
# Auditor                    4717582  14471.110429   326  36.889571
# Diretor de Manufatura      2099450  14478.965517   145  38.296552
# Diretor de Pesquisa        1206444  15080.550000    80  44.000000
# Gestor                     1544237  15139.578431   102  46.764706
# Pesquisador                4066717  13927.113014   292  34.236301
# Representante da Saude     1886426  14400.198473   131  39.809160
# Representante de Setor     1185091  14278.204819    83  30.361446
# Tecnico de Laboratorio     3643110  14066.061776   259  34.096525
# Tecnico de TI               691205  13292.403846    52  35.500000

# %%
base.groupby(['CARGO']).agg({'RENDAMENSAL':['sum','mean','count'],
                             'IDADE': 'mean'
                            })
# Out:
#                        RENDAMENSAL                          IDADE
#                                sum          mean count       mean
# CARGO
# Auditor                    4717582  14471.110429   326  36.889571
# Diretor de Manufatura      2099450  14478.965517   145  38.296552
# Diretor de Pesquisa        1206444  15080.550000    80  44.000000
# Gestor                     1544237  15139.578431   102  46.764706
# Pesquisador                4066717  13927.113014   292  34.236301
# Representante da Saude     1886426  14400.198473   131  39.809160
# Representante de Setor     1185091  14278.204819    83  30.361446
# Tecnico de Laboratorio     3643110  14066.061776   259  34.096525
# Tecnico de TI               691205  13292.403846    52  35.500000

# %%
import pandas as pd
base = pd.read_csv('Banco de Dados Laboratorio.csv')

# %%
base.columns
# Out:
# Index(['IDCOLABORADOR', 'IDADE', 'INSATISTFEITO', 'STATUSCIVIL', 'GENERO',
#        'NOME', 'SETOR', 'CARGO', 'CEP', 'NIVELEDUCACAO', 'FORMACAO',
#        'RENDAMENSAL', 'DESCONTOULTIMAFATURA', 'ANONAEMPRESA',
#        'ANOSMESMAPOSICAO', 'ANOSDESDEULTIMAPROMOCAO'],
#       dtype='object')

# %%
colunas = ['IDADE',
           'INSATISTFEITO',
           'STATUSCIVIL',
           'GENERO',
           'NOME',
           'SETOR',
           'CARGO' ]

# %%
base[colunas]
# Out:
#       IDADE INSATISTFEITO STATUSCIVIL     GENERO            NOME      SETOR  \
# 0        41           Sim    Solteiro   Feminino  Maria da Silva  Alimentos
# 1        33           Nao      Casado   Feminino    Ana Oliveira      Saude
# 2        59           Nao      Casado   Feminino  Juliana Santos      Saude
# 3        29           Nao    Solteiro   Feminino  Fernanda Costa      Saude
# 4        29           Nao  Divorciado   Feminino    Beatriz Lima      Saude
# ...     ...           ...         ...        ...             ...        ...
# 1465     36           Nao      Casado  Masculino     Otavio Dias      Saude
# 1466     39           Nao      Casado  Masculino    Pedro Barros      Saude
# 1467     27           Nao      Casado  Masculino     Ravi Santos      Saude
# 1468     49           Nao      Casado  Masculino      Theo Costa  Alimentos
# 1469     34           Nao      Casado  Masculino  Eduardo Mendes      Saude
#
#                        CARGO
# ...

# %%
base.pivot_table(values='RENDAMENSAL', index='CARGO', columns='STATUSCIVIL', aggfunc='mean')
# Out:
# STATUSCIVIL                   Casado    Divorciado      Solteiro
# CARGO
# Auditor                 14463.172185  13655.652174  15013.235849
# Diretor de Manufatura   12617.552239  15393.444444  16664.523810
# Diretor de Pesquisa     16304.500000  11945.000000  16428.315789
# Gestor                  14528.267857  16700.086957  15067.478261
# Pesquisador             13866.065574  14644.145161  13584.444444
# Representante da Saude  13989.295082  14785.323529  14732.722222
# Representante de Setor  13973.411765  13527.636364  14768.184211
# Tecnico de Laboratorio  14001.275862  13867.818182  14275.363636
# Tecnico de TI           12329.642857  14427.500000  14399.000000

# %% [markdown]
# ANÁLISE EXPLORATÓRIA DE DADOS

# %% [markdown]
# 12/09/2024 - QUINTA-FEIRA

# %% [markdown]
# DADOS QUALITATIVOS

# %%
base['CARGO'].value_counts(dropna=False) # frequencia absoluta
# Out:
# CARGO
# Auditor                   326
# Pesquisador               292
# Tecnico de Laboratorio    259
# Diretor de Manufatura     145
# Representante da Saude    131
# Gestor                    102
# Representante de Setor     83
# Diretor de Pesquisa        80
# Tecnico de TI              52
# Name: count, dtype: int64

# %%
base['CARGO'].value_counts(normalize=True, dropna=False) # frequencia relativa
# Out:
# CARGO
# Auditor                   0.221769
# Pesquisador               0.198639
# Tecnico de Laboratorio    0.176190
# Diretor de Manufatura     0.098639
# Representante da Saude    0.089116
# Gestor                    0.069388
# Representante de Setor    0.056463
# Diretor de Pesquisa       0.054422
# Tecnico de TI             0.035374
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt # biblioteca para construção gráfica

# %%
import seaborn as sns # gráficos mais estilosos

# %%
freq_cargo = base['CARGO'].value_counts(dropna=False) # frequencia absoluta

# %%
freq_cargo
# Out:
# CARGO
# Auditor                   326
# Pesquisador               292
# Tecnico de Laboratorio    259
# Diretor de Manufatura     145
# Representante da Saude    131
# Gestor                    102
# Representante de Setor     83
# Diretor de Pesquisa        80
# Tecnico de TI              52
# Name: count, dtype: int64

# %%
type(freq_cargo)
# Out:
# pandas.core.series.Series

# %%
plt.bar(freq_cargo.index, freq_cargo.values)
plt.title('Frequencia Absoluta de Cargo')
plt.xticks(rotation=90)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.show()

# %%
plt.bar(freq_cargo.index, freq_cargo.values)
plt.title('Frequencia Absoluta de Cargo')
plt.xticks(rotation=90)
plt.ylabel('Frequencia')
plt.xlabel('Cargo')
plt.show()

# %%
plt.bar(freq_cargo.index, freq_cargo.values)
plt.title('Frequencia Absoluta de Cargo')
plt.xticks(rotation=90)
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %%
plt.bar(freq_cargo.index,freq_cargo.values)
plt.title('Frequência Absoluta de Cargo')
plt.xticks(rotation=90)
plt.ylabel('Frequencia')
plt.xlabel('Cargo')

for i, value in enumerate(freq_cargo.values):
    plt.text(i, value, str(value), ha='center', va='bottom') 
plt.show()

# %%
barra = plt.barh(freq_cargo.index,freq_cargo.values)
plt.title('Frequência Absoluta de Cargo')
#plt.xticks(rotation=90)
plt.ylabel('Cargo')
plt.xlabel('Frequência Absoluta')

for i in barra:
    plt.text(i.get_width(),i.get_y() + i.get_height()/2, f'{i.get_width()}', va='center')

# %%
plt.pie(freq_cargo.values, labels = freq_cargo.values)
plt.show()

# %%
plt.pie(freq_cargo.values,
        labels = freq_cargo.index,
        autopct='%.2f%%')
plt.title('Frequência Relativa de Cargo')
plt.show()

# %%
#Frequência Absoluta status civil
freq_status = base['STATUSCIVIL'].value_counts(dropna=False)

#Opcional avançado: Solução Deiner
plt.bar(freq_status.index,freq_status.values)
plt.title('Frequência Absoluta de Status')
plt.xticks(rotation=90)
plt.ylabel('Frequencia')
plt.xlabel('Cargo')

for i, value in enumerate(freq_status.values):
    plt.text(i, value, str(value), ha='center', va='bottom') 
plt.show()

# %%
plt.pie(freq_status.values, 
        labels = freq_status.index,
        autopct='%.2f%%')
plt.title('Frequência Relativa de Status')
plt.show()

# %%
pd.crosstab(base['CARGO'], base['SETOR'])
# Out:
# SETOR                   Alimentos  Medicamentos  Saude
# CARGO
# Auditor                       326             0      0
# Diretor de Manufatura           0             0    145
# Diretor de Pesquisa             0             0     80
# Gestor                         37            11     54
# Pesquisador                     0             0    292
# Representante da Saude          0             0    131
# Representante de Setor         83             0      0
# Tecnico de Laboratorio          0             0    259
# Tecnico de TI                   0            52      0

# %%
cargo = base['CARGO']
setor = base['SETOR']
pd.crosstab(cargo, setor)
# Out:
# SETOR                   Alimentos  Medicamentos  Saude
# CARGO
# Auditor                       326             0      0
# Diretor de Manufatura           0             0    145
# Diretor de Pesquisa             0             0     80
# Gestor                         37            11     54
# Pesquisador                     0             0    292
# Representante da Saude          0             0    131
# Representante de Setor         83             0      0
# Tecnico de Laboratorio          0             0    259
# Tecnico de TI                   0            52      0

# %%
cargo = base['CARGO']
setor = base['SETOR']
genero = base['GENERO']
pd.crosstab(cargo, [setor,genero])
# Out:
# SETOR                  Alimentos           Medicamentos              Saude  \
# GENERO                  Feminino Masculino     Feminino Masculino Feminino
# CARGO
# Auditor                      132       194            0         0        0
# Diretor de Manufatura          0         0            0         0       72
# Diretor de Pesquisa            0         0            0         0       33
# Gestor                        19        18            4         7       24
# Pesquisador                    0         0            0         0      114
# Representante da Saude         0         0            0         0       51
# Representante de Setor        38        45            0         0        0
# Tecnico de Laboratorio         0         0            0         0       85
# Tecnico de TI                  0         0           16        36        0
#
# SETOR
# GENERO                 Masculino
# CARGO
# Auditor                        0
# Diretor de Manufatura         73
# ...

# %% [markdown]
#     DADOS QUANTITATIVOS

# %%
# Calcular Q1 e Q3
Q1 = base['RENDAMENSAL'].quantile(0.25)
Q3 = base['RENDAMENSAL'].quantile(0.75)

# Calcular o IQR
IQR = Q3 - Q1

# Definir os limites para outliers
limite_inf = Q1 - 1.5 * IQR
limite_sup = Q3 + 1.5 * IQR

# %%
base.describe()
# Out:
#        IDCOLABORADOR        IDADE          CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count    1470.000000  1470.000000  1426.000000    1470.000000   1470.000000
# mean     1024.865306    36.923810     9.140252       2.912925  14313.103401
# std       602.024335     9.135373     8.065954       1.024165   7117.786044
# min         1.000000    18.000000     1.000000       1.000000   2094.000000
# 25%       491.250000    30.000000     2.000000       2.000000   8047.000000
# 50%      1020.500000    36.000000     7.000000       3.000000  14235.500000
# 75%      1555.750000    43.000000    14.000000       4.000000  20461.500000
# max      2068.000000    60.000000    29.000000       5.000000  26999.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count   1470.000000       1470.000000              1470.000000
# mean       7.008163          4.229252                 2.187755
# std        6.126525          3.623137                 3.222430
# ...

# %%
limite_inf = Q1 - 1.5 * IQR

# %%
limite_inf
# Out:
# -10574.75

# %%
limite_sup = Q3 + 1.5 * IQR

# %%
limite_sup
# Out:
# 39083.25

# %%
base.describe()
# Out:
#        IDCOLABORADOR        IDADE          CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count    1470.000000  1470.000000  1426.000000    1470.000000   1470.000000
# mean     1024.865306    36.923810     9.140252       2.912925  14313.103401
# std       602.024335     9.135373     8.065954       1.024165   7117.786044
# min         1.000000    18.000000     1.000000       1.000000   2094.000000
# 25%       491.250000    30.000000     2.000000       2.000000   8047.000000
# 50%      1020.500000    36.000000     7.000000       3.000000  14235.500000
# 75%      1555.750000    43.000000    14.000000       4.000000  20461.500000
# max      2068.000000    60.000000    29.000000       5.000000  26999.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count   1470.000000       1470.000000              1470.000000
# mean       7.008163          4.229252                 2.187755
# std        6.126525          3.623137                 3.222430
# ...

# %% [markdown]
# outliers = dados [(dados < limite_inf ) |
# (df > limite_sup )]

# %%
outliers = base[(base['RENDAMENSAL'] < limite_inf) | 
                (base['RENDAMENSAL'] > limite_sup)]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [IDCOLABORADOR, IDADE, INSATISTFEITO, STATUSCIVIL, GENERO, NOME, SETOR, CARGO, CEP, NIVELEDUCACAO, FORMACAO, RENDAMENSAL, DESCONTOULTIMAFATURA, ANONAEMPRESA, ANOSMESMAPOSICAO, ANOSDESDEULTIMAPROMOCAO]
# Index: []

# %%
import seaborn as sns

# %%
sns.boxplot(y = base['RENDAMENSAL'])
plt.show()

# %%
sns.boxplot(y = 'RENDAMENSAL', data=base)
plt.show()

# %%
sns.boxplot(y = 'RENDAMENSAL', x = 'CARGO',
            data=base)
# Out:
# <Axes: xlabel='CARGO', ylabel='RENDAMENSAL'>

# %%
import seaborn as sns
sns.boxplot(y = 'IDADE',
            x = 'CARGO', 
            data=base)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 12/09/2024 - SEXTA-FEIRA

# %%
sns.boxplot(base['IDADE'])
plt.show()

# %%
sns.boxplot(base['ANONAEMPRESA'])
plt.show()

# %%
base
# Out:
#       IDCOLABORADOR  IDADE INSATISTFEITO STATUSCIVIL     GENERO  \
# 0                 1     41           Sim    Solteiro   Feminino
# 1                 5     33           Nao      Casado   Feminino
# 2                10     59           Nao      Casado   Feminino
# 3                15     29           Nao    Solteiro   Feminino
# 4                20     29           Nao  Divorciado   Feminino
# ...             ...    ...           ...         ...        ...
# 1465           2061     36           Nao      Casado  Masculino
# 1466           2062     39           Nao      Casado  Masculino
# 1467           2064     27           Nao      Casado  Masculino
# 1468           2065     49           Nao      Casado  Masculino
# 1469           2068     34           Nao      Casado  Masculino
#
#                 NOME      SETOR                   CARGO   CEP  NIVELEDUCACAO  \
# 0     Maria da Silva  Alimentos                 Auditor   1.0              2
# ...

# %%
sns.boxplot(base['RENDAMENSAL'])
plt.show()

# %%
sns.boxplot(x=base['ANONAEMPRESA'], y=base['CARGO'])
plt.show()

# %%
base[base['CARGO'] == 'Tecnico de TI'].describe()
# Out:
#        IDCOLABORADOR      IDADE        CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count      52.000000  52.000000  50.000000      52.000000     52.000000
# mean     1236.326923  35.500000   8.020000       2.884615  13292.403846
# std       580.294338   7.937254   7.530862       1.022374   7549.170520
# min       103.000000  19.000000   1.000000       1.000000   2097.000000
# 25%       811.750000  29.750000   2.000000       2.000000   7053.250000
# 50%      1301.500000  35.000000   6.000000       3.000000  11559.000000
# 75%      1754.750000  41.250000  10.750000       3.250000  19939.750000
# max      2040.000000  59.000000  26.000000       5.000000  26894.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count     52.000000         52.000000                52.000000
# mean       5.326923          3.134615                 1.269231
# std        3.655354          2.722663                 1.646331
# min        1.000000          0.000000                 0.000000
# ...

# %%
tecnico_TI = base[base['CARGO'] == 'Tecnico de TI'].describe()

# %%
tecnico_TI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   IDCOLABORADOR            8 non-null      float64
#  1   IDADE                    8 non-null      float64
#  2   CEP                      8 non-null      float64
#  3   NIVELEDUCACAO            8 non-null      float64
#  4   RENDAMENSAL              8 non-null      float64
#  5   ANONAEMPRESA             8 non-null      float64
#  6   ANOSMESMAPOSICAO         8 non-null      float64
#  7   ANOSDESDEULTIMAPROMOCAO  8 non-null      float64
# dtypes: float64(8)
# memory usage: 576.0+ bytes

# %%
sns.boxplot(x=base['IDADE'], y=base['SETOR'])
plt.show()

# %%
auditor = base[base['CARGO'] == 'Auditor'].describe()

# %%
auditor
# Out:
#        IDCOLABORADOR       IDADE         CEP  NIVELEDUCACAO   RENDAMENSAL  \
# count     326.000000  326.000000  318.000000     326.000000    326.000000
# mean     1051.092025   36.889571    9.632075       3.015337  14471.110429
# std       605.506281    8.092546    8.137996       0.996800   7173.686244
# min         1.000000   24.000000    1.000000       1.000000   2137.000000
# 25%       513.750000   31.000000    3.000000       2.000000   8387.500000
# 50%      1036.500000   35.000000    8.000000       3.000000  14242.000000
# 75%      1584.500000   41.000000   14.000000       4.000000  20747.250000
# max      2065.000000   60.000000   29.000000       5.000000  26997.000000
#
#        ANONAEMPRESA  ANOSMESMAPOSICAO  ANOSDESDEULTIMAPROMOCAO
# count    326.000000        326.000000               326.000000
# mean       7.496933          4.855828                 2.484663
# std        5.112728          3.450852                 3.343615
# ...

# %%
lista = ['sum','mean','count','std']

base.groupby(['CARGO','GENERO']).agg({
                              'IDADE':lista
                            })
# Out:
#                                  IDADE
#                                    sum       mean count       std
# CARGO                  GENERO
# Auditor                Feminino   4994  37.833333   132  8.678452
#                        Masculino  7032  36.247423   194  7.624654
# Diretor de Manufatura  Feminino   2782  38.638889    72  9.131752
#                        Masculino  2771  37.958904    73  8.138452
# Diretor de Pesquisa    Feminino   1383  41.909091    33  8.106185
#                        Masculino  2137  45.468085    47  7.534994
# Gestor                 Feminino   2241  47.680851    47  6.950466
#                        Masculino  2529  45.981818    55  6.900056
# Pesquisador            Feminino   3875  33.991228   114  8.753756
#                        Masculino  6122  34.393258   178  8.508710
# Representante da Saude Feminino   1984  38.901961    51  6.926052
#                        Masculino  3231  40.387500    80  8.912363
# ...

# %% [markdown]
# EXERCÍCIOS
